# %% [markdown]
# <a href="https://colab.research.google.com/github/Alisha090706/OSTPractical/blob/main/OST_Practical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### OST Practical

print("Date: 25-04-2026, Saturday")
print("OST Practical")

name = input("What is your name?: ")
age = int(input("What is your age?: "))
print("==================")

print("Your name: ", name)
print("Your age: ", age)
# Out:
# Date: 25-04-2026, Saturday
# OST Practical
# What is your name?: Alisha
# What is your age?: 19
# ...
# Your name:  Alisha
# Your age:  19
